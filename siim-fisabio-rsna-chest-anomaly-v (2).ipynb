# %%
# !mkdir -p /tmp/pip/cache/
# !cp ../input/segmentationmodelszip/pretrainedmodels-0.7.4.xyz /tmp/pip/cache/pretrainedmodels-0.7.4.tar.gz
# !cp ../input/segmentationmodelszip/segmentation_models_pytorch-0.0.1-py2.py3-none-any.whl /tmp/pip/cache/
# !cp ../input/segmentationmodelszip/torchfile-0.1.0.xyz /tmp/pip/cache/torchfile-0.1.0.tar.gz
# !cp ../input/segmentationmodelszip/torchnet-0.0.4.xyz /tmp/pip/cache/torchnet-0.0.4.tar.gz
# !cp ../input/segmentationmodelszip/torchvision-0.2.2-py2.py3-none-any.whl /tmp/pip/cache/
# !cp ../input/segmentationmodelszip/tqdm-4.19.9-py2.py3-none-any.whl /tmp/pip/cache/
# !cp ../input/segmentationmodelszip/visdom-0.1.8.8.xyz/visdom-0.1.8.8.xyz /tmp/pip/cache/visdom-0.1.8.8.tar.gz

# %%
# !ls /tmp/pip/cache
# Out:
# pretrainedmodels-0.7.4.tar.gz
# segmentation_models_pytorch-0.0.1-py2.py3-none-any.whl
# torchfile-0.1.0.tar.gz
# torchnet-0.0.4.tar.gz
# torchvision-0.2.2-py2.py3-none-any.whl
# tqdm-4.19.9-py2.py3-none-any.whl
# visdom-0.1.8.8.tar.gz

# %%
# !pip install --no-index --find-links /tmp/pip/cache/ segmentation-models-pytorch
# Out:
# Looking in links: /tmp/pip/cache/
# Processing /tmp/pip/cache/segmentation_models_pytorch-0.0.1-py2.py3-none-any.whl
# Processing /tmp/pip/cache/torchnet-0.0.4.tar.gz
# Processing /tmp/pip/cache/torchvision-0.2.2-py2.py3-none-any.whl
# Processing /tmp/pip/cache/pretrainedmodels-0.7.4.tar.gz
# Requirement already satisfied: torch in /opt/conda/lib/python3.7/site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.7.0)
# Requirement already satisfied: munch in /opt/conda/lib/python3.7/site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (2.5.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.59.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from torchnet==0.0.4->segmentation-models-pytorch) (1.15.0)
# Processing /tmp/pip/cache/visdom-0.1.8.8.tar.gz
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torchvision==0.2.2->segmentation-models-pytorch) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision==0.2.2->segmentation-models-pytorch) (7.2.0)
# Processing /tmp/pip/cache/tqdm-4.19.9-py2.py3-none-any.whl
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (0.6)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from visdom->torchnet==0.0.4->segmentation-models-pytorch) (1.5.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from visdom->torchnet==0.0.4->segmentation-models-pytorch) (2.25.1)
# Requirement already satisfied: tornado in /opt/conda/lib/python3.7/site-packages (from visdom->torchnet==0.0.4->segmentation-models-pytorch) (6.1)
# Requirement already satisfied: pyzmq in /opt/conda/lib/python3.7/site-packages (from visdom->torchnet==0.0.4->segmentation-models-pytorch) (22.0.3)
# Processing /tmp/pip/cache/torchfile-0.1.0.tar.gz
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.7/site-packages (from visdom->torchnet==0.0.4->segmentation-models-pytorch) (0.57.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->visdom->torchnet==0.0.4->segmentation-models-pytorch) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->visdom->torchnet==0.0.4->segmentation-models-pytorch) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->visdom->torchnet==0.0.4->segmentation-models-pytorch) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->visdom->torchnet==0.0.4->segmentation-models-pytorch) (2020.12.5)
# Building wheels for collected packages: pretrainedmodels, torchnet, visdom, torchfile
# done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60963 sha256=3c67218c8c16c8b9a989183f34425ced56e0bfa07b392cddd4ec98edea8146e4
#   Stored in directory: /root/.cache/pip/wheels/10/1f/03/61c3da39f4907ac6ad69ce8078e5be835c4681b842d110d52f
# done
#   Created wheel for torchnet: filename=torchnet-0.0.4-py3-none-any.whl size=29741 sha256=7cdafa8e80ce4c74c7c7d051e68e79c4f768b5eb0d48b80201185fd7aa71c8f6
#   Stored in directory: /root/.cache/pip/wheels/a5/f7/a7/a0cc5d0c9dd698d29d091f17e2360b0fc08fb2582e5ec605d9
# done
#   Created wheel for visdom: filename=visdom-0.1.8.8-py3-none-any.whl size=1350602 sha256=51c9df0893ea53644018459da2ec02b508cd350180fa65de9280394805d5e4d2
#   Stored in directory: /root/.cache/pip/wheels/c1/77/ea/b722d192cf8c05e0292c227c73b55c5282199fb00588c96637
# done
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5711 sha256=68e2efae9f5a9c3e776d54202e678a7866e33fbdf13e6f73f68ffdcd11c69c38
#   Stored in directory: /root/.cache/pip/wheels/f4/4c/be/5f73e12c23a2512c7d2adcfffaba260550c434256fcdea36d2
# Successfully built pretrainedmodels torchnet visdom torchfile
# Installing collected packages: tqdm, torchfile, visdom, torchvision, torchnet, pretrainedmodels, segmentation-models-pytorch
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.8.1
#     Uninstalling torchvision-0.8.1:
#       Successfully uninstalled torchvision-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.5.1 requires tqdm>=4.27, but you have tqdm 4.19.9 which is incompatible.
# tpot 0.11.7 requires tqdm>=4.36.1, but you have tqdm 4.19.9 which is incompatible.
# tensorpack 0.11 requires tqdm>4.29.0, but you have tqdm 4.19.9 which is incompatible.
# spacy 2.3.5 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.19.9 which is incompatible.
# shap 0.39.0 requires tqdm>4.25.0, but you have tqdm 4.19.9 which is incompatible.
# pytorch-lightning 1.2.8 requires tqdm>=4.41.0, but you have tqdm 4.19.9 which is incompatible.
# papermill 2.3.3 requires tqdm>=4.32.2, but you have tqdm 4.19.9 which is incompatible.
# pandas-profiling 2.11.0 requires tqdm>=4.48.2, but you have tqdm 4.19.9 which is incompatible.
# implicit 0.4.4 requires tqdm>=4.27, but you have tqdm 4.19.9 which is incompatible.
# featuretools 0.23.3 requires tqdm>=4.32.0, but you have tqdm 4.19.9 which is incompatible.
# fbprophet 0.7.1 requires tqdm>=4.36.1, but you have tqdm 4.19.9 which is incompatible.
# fastai 2.3.0 requires torchvision<0.9,>=0.8, but you have torchvision 0.2.2 which is incompatible.
# easyocr 1.3.0.1 requires torchvision>=0.5, but you have torchvision 0.2.2 which is incompatible.
# dipy 1.4.0 requires tqdm>=4.30.0, but you have tqdm 4.19.9 which is incompatible.
# autogluon-core 0.1.0 requires tqdm>=4.38.0, but you have tqdm 4.19.9 which is incompatible.
# allennlp 2.3.0 requires torchvision<0.10.0,>=0.8.1, but you have torchvision 0.2.2 which is incompatible.
# Successfully installed pretrainedmodels-0.7.4 segmentation-models-pytorch-0.0.1 torchfile-0.1.0 torchnet-0.0.4 torchvision-0.2.2 tqdm-4.19.9 visdom-0.1.8.8

# %%
# !pip install segmentation-models-pytorch
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch

# SIIM-FISABIO-RSNA-Chest-Anomaly-64_60-256_40_v34

# %%
import os
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import matplotlib
import segmentation_models_pytorch as smp
import cv2
import pydicom as dicom
import torch
import ast # https://www.geeksforgeeks.org/python-convert-a-string-representation-of-list-into-list/
from skimage import exposure
import segmentation_models_pytorch as smp
from PIL import Image 
import glob

# %%
# !mkdir -p /root/.cache/torch/hub/checkpoints/
# !cp ../input/resnet34/resnet34-333f7ec4.pth /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# !cp ../input/resnet50/resnet50-19c8e357.pth /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# !cp ../input/vgg19/vgg19-dcbb9e9d.pth /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth

# %% [markdown]
# # Preprocess DataFrames

# %%
train_image_df = pd.read_csv('../input/siim-covid19-detection/train_image_level.csv')
train_study_df = pd.read_csv('../input/siim-covid19-detection/train_study_level.csv')

# %%
try:
    train_study_df['id'] = train_study_df['id'].str.replace('_study',"")
    train_study_df.rename(columns={'id': 'StudyInstanceUID'}, inplace=True)
    
except KeyError:
    print(train_study_df.head())

# %%
train_image_df = train_image_df.merge(train_study_df, on='StudyInstanceUID')
# train_image_df.head(4)

# %%
class_names = ['Negative for Pneumonia', 'Typical Appearance', 'Indeterminate Appearance', 'Atypical Appearance']
classes = {0: 'negative', 1: 'typical', 2: 'indeterminate', 3: 'atypical'}
study_label = "study_label"

# %%
try:
#     train_image_df.loc[train_image_df[class_names[0]] == 1, study_label] = 'negative'
#     train_image_df.loc[train_image_df[class_names[1]] == 1, study_label] = 'typical'
#     train_image_df.loc[train_image_df[class_names[2]] == 1, study_label] = 'indeterminate'
#     train_image_df.loc[train_image_df[class_names[3]] == 1, study_label] = 'atypical'
    train_image_df.loc[train_image_df[class_names[0]] == 1, study_label] = 0
    train_image_df.loc[train_image_df[class_names[1]] == 1, study_label] = 1
    train_image_df.loc[train_image_df[class_names[2]] == 1, study_label] = 2
    train_image_df.loc[train_image_df[class_names[3]] == 1, study_label] = 3

    train_image_df.drop(class_names, axis=1, inplace=True)
    train_image_df.head(4)
    
except KeyError:
    print(train_image_df.head(4))

# %% [markdown]
# # Exaple of Image Data

# %%
from pydicom import dcmread
from pydicom.pixel_data_handlers.util import convert_color_space

# %%
def get_image(id):
    path_train = '/kaggle/input/siim-covid19-detection/' + 'train/' + train_image_df.loc[id, 'StudyInstanceUID']
    last_folder_in_path = os.listdir(path_train)[0]
    path_train = path_train + '/{}/'.format(last_folder_in_path)
    img_id = train_image_df.loc[id, 'id'].replace('_image','.dcm')
#     print(path_train + img_id)
    data_file = dicom.dcmread(path_train + img_id)
    img = data_file.pixel_array
    img_2d = img.astype(float)
    img_2d_scaled = (np.maximum(img_2d, 0) / img_2d.max() * 255.0)
    img_2d_scaled = np.uint8(img_2d_scaled)
    img = np.stack((img, ) * 3, axis=-1)
    
    return img_2d_scaled

# %%
train_image_label_df = train_image_df[["id", "study_label"]].copy()
# train_image_label_df.head()

# %%
def draw_image(id):
    figure, ax = plt.subplots(1)

    img = get_image(id)
    if (train_image_df.loc[id, 'boxes'] == train_image_df.loc[id, 'boxes']):
        boxes = ast.literal_eval(train_image_df.loc[id, 'boxes'])

        for box in boxes:
            print(boxes) 
            
            mask = cv2.rectangle(img, (int(box['x']), int(box['y'])), 
                                      (int(box['x'] + box['width']), int(box['y'] + box['height'])), 
                                      (0, 0, 255), -1)
            
            ax.imshow(img)
            ax.set_title(train_image_df.loc[id, 'study_label'].split(' ')[0])

# %%
def get_mask(id):
    img = get_image(id)
    y = len(img[0])
    x = len(img)
    img = np.zeros((x, y, 3), np.uint8)
    
    if (train_image_df.loc[id, 'boxes'] == train_image_df.loc[id, 'boxes']):
        boxes = ast.literal_eval(train_image_df.loc[id, 'boxes'])
        
        for box in boxes:      
            mask = cv2.rectangle(img, (int(box['x']), int(box['y'])), 
                                      (int(box['x'] + box['width']), int(box['y'] + box['height'])), 
                                      (0, 0, 255), -1)
    return img

# %%
plt.imshow(get_image(0))

# %%
# draw_image(0)

# %%
# plt.imshow(get_mask(0))

# %%
train_image_label_df['id'] = train_image_label_df['id'].str.replace('_image', '.png')

# %% [markdown]
# # Train, Validation, Test Splits | for the Segmentation model

# %%
# remove previous folders
########## RM RF ##########
try:
    import shutil
    shutil.rmtree("train_images")
    shutil.rmtree("train_masks")
    shutil.rmtree("test_images")
    shutil.rmtree("test_masks")
    shutil.rmtree("validation_images")
    shutil.rmtree("validation_masks")
except:
    pass

# create folders to store data
# !mkdir train_images
# !mkdir train_masks

# !mkdir test_images
# !mkdir test_masks

# !mkdir validation_images
# !mkdir validation_masks

# %%
# define data volume
test_data = 0.1
validation_data = 0.2
skip = 6
samples = 1000 * skip

# %%
stop_train = int(samples * (1 - (test_data + validation_data)))

start_test = int(stop_train)
stop_test = int(samples * (1 - validation_data))

start_val = int(stop_test)
stop_val = int(samples)

# %%
remove_idxs_train = []
remove_idxs_test = []
remove_idxs_val = []
size = 64

def create_imgs():
    for i in range(0, stop_train):
        if i % skip == 0:
            try:
                name = train_image_label_df.loc[i, 'id']

                img = get_image(i)
                img = np.array(img)
                img = cv2.resize(img, (size, size))
                cv2.imwrite(f"./train_images/{name}", img)

                mask = get_mask(i)
                mask = np.array(mask)
                mask = cv2.resize(mask, (size, size))
                cv2.imwrite(f"./train_masks/{name}", mask)

            except (FileNotFoundError, RuntimeError) as e:
                remove_idxs_train.append(i)
                print(f"train file {name} not found at index {i}")
                pass
        else:
            remove_idxs_train.append(i)
        
    for j in range(start_test, stop_test):
        if j % skip == 0:
            try:
                name = train_image_label_df.loc[j, 'id']

                img = get_image(j)
                img = np.array(img)
                img = cv2.resize(img, (size, size))
                cv2.imwrite(f"./test_images/{name}", img)

                mask = get_mask(j)
                mask = np.array(mask)
                mask = cv2.resize(mask, (size, size))
                cv2.imwrite(f"./test_masks/{name}", mask)

            except (FileNotFoundError, RuntimeError) as e:
                remove_idxs_test.append(j)
                print(f"test file {name} not found at index {j}")
                pass
        else:
            remove_idxs_test.append(j)
        
    for k in range(start_val, stop_val):
        if k % skip == 0:
            try:
                name = train_image_label_df.loc[k, 'id']

                img = get_image(k)
                img = np.array(img)
                img = cv2.resize(img, (size, size))
                cv2.imwrite(f"./validation_images/{name}", img)

                mask = get_mask(k)
                mask = np.array(mask)
                mask = cv2.resize(mask, (size, size))
                cv2.imwrite(f"./validation_masks/{name}", mask)

            except (FileNotFoundError, RuntimeError) as e:
                remove_idxs_val.append(k)
                print(f"test file {name} not found at index {k}")
                pass
        else:
            remove_idxs_val.append(k)
        
create_imgs()
# Out:
# train file 05c063f5cef5.png not found at index 138
# train file 04f41a8958f7.png not found at index 150
# train file 11f46d9df786.png not found at index 180
# train file 9a335ce0bca4.png not found at index 204
# train file 1c0d8460a527.png not found at index 234
# train file 19ef72ca62b8.png not found at index 252
# train file 08acae0bf785.png not found at index 258
# train file 0a0cbc610620.png not found at index 294
# train file 0b020a7aff0a.png not found at index 318
# train file c7925ab50eb0.png not found at index 354
# train file 0e2691505e53.png not found at index 408
# train file 2204baf77803.png not found at index 474
# train file 12e97ed89297.png not found at index 540
# train file 13ff01cf36f8.png not found at index 576
# train file 16c9f1b33188.png not found at index 630
# train file 1701be774ecb.png not found at index 636
# train file e73f2cc047ad.png not found at index 642
# train file 19fc87ff0612.png not found at index 708
# train file 33c95dbfe335.png not found at index 714
# train file 1b3dcbce0fa2.png not found at index 744
# train file fa447a409bd6.png not found at index 750
# train file 84ed5f7f71bf.png not found at index 780
# train file a1fa5f79671d.png not found at index 804
# train file 1df3e98f79be.png not found at index 810
# train file 215885f7fd71.png not found at index 900
# train file 336d2b8392f9.png not found at index 918
# train file 244776b92aaa.png not found at index 978
# train file 2512da499679.png not found at index 996
# train file 3f79915dd256.png not found at index 1104
# train file 684230477525.png not found at index 1176
# train file 2da1eb17b0b7.png not found at index 1212
# train file 2e37fb0a6193.png not found at index 1230
# train file 2ed1dfce5a95.png not found at index 1242
# train file 32222cc776a2.png not found at index 1332
# train file 646a6a0a9bf2.png not found at index 1344
# train file bb36f3d3ac71.png not found at index 1368
# train file 4cebe94f1fa3.png not found at index 1452
# train file 394536fc0dca.png not found at index 1524
# train file 39cd89772e5e.png not found at index 1536
# train file d342f75ccb55.png not found at index 1542
# train file bfefe70b56ca.png not found at index 1674
# train file 59bc532be971.png not found at index 1722
# train file 41751eb3b214.png not found at index 1734
# train file 744427c7dff8.png not found at index 1758
# train file 4733caa4742e.png not found at index 1872
# train file 49c596c8b1a1.png not found at index 1932
# train file 4cf41c062d0c.png not found at index 2016
# train file 4f0abed3f35c.png not found at index 2076
# train file 51d04316f2c9.png not found at index 2160
# train file 51eb9085f328.png not found at index 2166
# train file 6e5946091b8a.png not found at index 2190
# train file 5b5f7675f4cc.png not found at index 2394
# train file 5e79f836af2c.png not found at index 2472
# train file 603ffc1653fd.png not found at index 2508
# train file 64378532251b.png not found at index 2616
# train file 685114c3c9fd.png not found at index 2724
# train file df565bcf3504.png not found at index 2838
# train file 88e7702b49c4.png not found at index 3084
# train file f6462d1bf586.png not found at index 3132
# train file 835e81040e61.png not found at index 3396
# train file 838c8d86cd36.png not found at index 3402
# train file 847f48f57169.png not found at index 3420
# train file d19ed8d811ad.png not found at index 3450
# train file 8ab8682e8bc6.png not found at index 3558
# train file 90a509d16478.png not found at index 3726
# train file 9b2d4652ad72.png not found at index 3966
# train file 9bc4d429d4e8.png not found at index 3978
# train file e5fc2fa92e65.png not found at index 4014
# train file a0178e3a0d8f.png not found at index 4068
# train file a3d4029a671d.png not found at index 4104
# test file a648b88334e7.png not found at index 4212
# test file ab55abb953d1.png not found at index 4326
# test file ab91cf190fdf.png not found at index 4332
# test file ae3d5da58736.png not found at index 4398
# test file ae8fecc25309.png not found at index 4410
# test file afed0cd3c9a7.png not found at index 4440
# test file b3eae4881218.png not found at index 4530
# test file b621bc3532ca.png not found at index 4572
# test file b689306ef723.png not found at index 4584
# test file b7eb26ddf5a3.png not found at index 4626
# test file b94286e2c027.png not found at index 4662
# test file b9f6129171e3.png not found at index 4680
# test file c04124bd92d8.png not found at index 4842
# test file c0e8c63f22c5.png not found at index 4854
# test file c2596fa5fc65.png not found at index 4884
# test file db55457e9cd2.png not found at index 5004
# test file f7f759f7a4f1.png not found at index 5058
# test file df3d32c8df06.png not found at index 5166
# test file d176b5544d10.png not found at index 5280
# test file d2896d7a3da9.png not found at index 5316
# test file db27626f6cf2.png not found at index 5508
# test file db9f538fa315.png not found at index 5526
# test file dd4db2cfc1dc.png not found at index 5568
# test file e00f9fe0cce5.png not found at index 5622
# test file eeee42a62e29.png not found at index 5940

# %%
print(len(os.listdir("./train_images")))
print(len(os.listdir("./test_images")))
print(len(os.listdir("./validation_masks")))
# Out:
# 630
# 88
# 187

# %%
train_df = train_image_label_df
train_df = train_df.head(stop_train)
train_df = train_df.drop(remove_idxs_train) # TODO: fix deletion of features


test_df = train_image_label_df.iloc[start_test : stop_test]
test_df = test_df.drop(remove_idxs_test)

val_df = train_image_label_df.iloc[start_val : stop_val]
val_df = val_df.drop(remove_idxs_val)

# %% [markdown]
# # Custom Dataset

# %%
from torch.utils.data import DataLoader
from albumentations import Resize, Normalize, Compose
from albumentations.pytorch import ToTensorV2
from torchvision.transforms import ToTensor, Lambda
from torch.utils.data import Dataset
import math
import albumentations as album

import torch
import torch.nn as nn

# %%
class SegmentationDataset(Dataset):
    def __init__(
            self, 
            annotations_file, 
            img_dir, 
            mask_dir,
            augmentation=None, 
    ):
        
        self.img_labels = annotations_file
        self.img_dir = img_dir
        self.mask_dir = mask_dir

        self.augmentation = augmentation
    
        
    def __len__(self):
        try:
            return len(self.img_labels)
        except TypeError:
            return 1  
        
        
    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        mask_path = os.path.join(self.mask_dir, self.img_labels.iloc[idx, 0])
        
        image = Image.open(img_path)
        mask = Image.open(mask_path)    
    
        image = np.asarray(image).astype('float32')
        mask = np.asarray(mask).astype('float32')
        
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        image = np.stack((image, ) * 3, axis=0)
        image = (image / image.max() * 255).astype(np.float32)        
        
        mask = (mask / 255).astype(np.float32)
        if (mask.ndim == 3):
            mask = mask[:, :, 0]        

        mask = np.expand_dims(mask, axis=0)

            
        return image, mask

# %%
def get_training_augmentation():
    train_transform = [    
        Resize(64, 64),
        album.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5),
#         album.RGBShift(r_shift_limit=25, g_shift_limit=25, b_shift_limit=25, p=1),
#         album.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=1),
#         album.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        album.OneOf(
            [
                album.HorizontalFlip(p=0.5),
#                 album.VerticalFlip(p=0.5),
#                 album.RandomRotate90(p=0.75),
#                 album.CenterCrop(64, 64),
#                 album.GaussianBlur(p=0.25),
                album.InvertImg(p=0.35)
            ],
            p=0.75,
        ),
#         ToTensorV2(),
    ]
    return album.Compose(train_transform)

# %%
def get_validation_augmentation():
    train_transform = [    
        Resize(64, 64),
#         album.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#         ToTensorV2(),
    ]
    return album.Compose(train_transform)

# %%
# FOR TESTING
train_img_dir = "./train_images"
train_mask_dir = "./train_masks"
fig, ax = plt.subplots(1, 2)

augmented_dataset = SegmentationDataset(
    train_df, train_img_dir, train_mask_dir,
    augmentation=get_training_augmentation(),
)
img, mask = augmented_dataset[0]

print(img.shape, mask.shape)

img = img[0, :, :]
mask = mask[0, :, :]

# pixel_img = img[100, 100]
# print(pixel_img, img.max(), img.shape)
print(img.min(), img.max(), img.shape)
print(mask.min(), mask.max(), mask.shape)

ax[0].imshow(img);
ax[1].imshow(mask);
# Out:
# (3, 64, 64) (1, 64, 64)
# 1.1446507 255.0 (64, 64)
# 0.0 1.0 (64, 64)

# %% [markdown]
# # Prepare data for the model

# %%
train_img_dir = "./train_images"
train_mask_dir = "./train_masks"
validation_img_dir = "./validation_images"
validation_mask_dir = "./validation_masks"
test_img_dir = "./test_images"
test_mask_dir = "./test_masks"

# %%
ENCODER = "resnet50"
ENCODER_WEIGHTS = 'imagenet'
ACTIVATION = 'sigmoid'

model = smp.Unet(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
#     classes=1, 
    activation=ACTIVATION,
)

preprocess_func = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %%
training = True
train_logs_list, valid_logs_list = [], []
best_iou_score = -math.inf

if not training:
    model_dir = '../input/modelv2/best_model_test (6).pth'
    model = torch.load(model_dir)

# %%
train_dataset = SegmentationDataset(
    train_df, train_img_dir, train_mask_dir,
    augmentation=get_training_augmentation(),
)

valid_dataset = SegmentationDataset(
    val_df, validation_img_dir, validation_mask_dir,
    augmentation=get_validation_augmentation(),
)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=4)

# %%
train_features, train_masks = next(iter(train_loader))

# %%
print(f"Feature batch shape: {train_features.size()}")
print(f"Masks batch shape: {train_masks.size()}")
# Out:
# Feature batch shape: torch.Size([8, 3, 64, 64])
# Masks batch shape: torch.Size([8, 1, 64, 64])

# %%
index = 0
fig, ax = plt.subplots(1, 2)

img = train_features[index].squeeze()
mask = train_masks[index].squeeze()

print(img.shape)
print(mask.shape)

img = img[0, :, :]

img = np.array(img)

# pixel = img[100, 100]
# print(pixel, img.max())

ax[0].imshow(img, cmap="gray");
ax[1].imshow(mask, cmap="gray");
# Out:
# torch.Size([3, 64, 64])
# torch.Size([64, 64])

# %% [markdown]
# # Model

# %%
# loss = nn.BCEWithLogitsLoss()
# loss.__name__ = "bceWithLogitLoss"
# # loss = smp.utils.losses.DiceLoss()
# # loss.__name__ = "DiceLoss"

# device = "cuda"
# metrics = [
#     smp.utils.metrics.IoUMetric(threshold=0.5),
# ]

# optimizer = torch.optim.Adam([dict(params=model.parameters(), lr=0.0001)])

# %%
# def train(model, number_epoches, model_name, device='cuda'):

#     # create epoch runners 
#     # it is a simple loop of iterating over dataloader`s samples
#     train_epoch = smp.utils.train.TrainEpoch(
#         model, 
#         loss=loss, 
#         metrics=metrics, 
#         optimizer=optimizer,
# #         device=device,
#         verbose=True,
#     )

#     valid_epoch = smp.utils.train.ValidEpoch(
#         model, 
#         loss=loss, 
#         metrics=metrics, 
# #         device=device,
#         verbose=True,
#     )
#     print("Start train model : ", model_name)
    
#     max_score = 0
#     for i in range(0, number_epoches):
#         print('\nEpoch: {}'.format(i))
#         train_logs = train_epoch.run(train_loader)
#         valid_logs = valid_epoch.run(valid_loader)

#         # do something (save model, change lr, etc.)
#         if max_score < valid_logs['iou']:
#             max_score = valid_logs['iou']
#             torch.save(model, 'best_model_test.pth')
#             print('Model saved!')

#         if i == 25:
#             optimizer.param_groups[0]['lr'] = 1e-5
#             print('Decrease decoder learning rate to 1e-5!')

# %%
# encoder = 'resnet50'
# encoder_weights ='imagenet'
# number_epoches = 20
# device = 'cuda'
# model = smp.Unet(encoder, encoder_weights=encoder_weights)

# %%
# train(model, number_epoches, 'unet', device=device)

# %%
# test_epoch_Unet = smp.utils.train.ValidEpoch(model, 
#                                         loss=loss, 
#                                         metrics=metrics, 
# #                                         device=device,
#                                         verbose=True)

# %%
# valid_logs = test_epoch_Unet.run(valid_loader) # on data validation
# train_logs = test_epoch_Unet.run(train_loader) # on data train

# %%
trainmodel = True
epochs = 50
# device = torch.device("cpu")
# loss = smp.utils.losses.JaccardLoss()
loss = smp.utils.losses.DiceLoss()
# loss = nn.BCEWithLogitsLoss()
loss.__name__ = "DiceLoss"
metrics = [ 
    smp.utils.metrics.IoUMetric(threshold=0.5),
#     smp.utils.metrics.FscoreMetric(eps=1.),
]
optimizer = torch.optim.Adam([dict(params=model.parameters(), lr=0.0001)])
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, epochs)
# lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.2, patience=2, cooldown=2)
# lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.2, patience=2)
# lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=1, T_mult=2, eta_min=5e-5,)

# %%
trainepoch = smp.utils.train.TrainEpoch(model, 
                                        loss=loss, 
                                        optimizer=optimizer, 
                                        metrics=metrics, 
#                                         device=device,
                                        verbose=True)

validepoch = smp.utils.train.ValidEpoch(model, 
                                        loss=loss, 
                                        metrics=metrics, 
#                                         device=device,
                                        verbose=True)

# %%
# %%time

for i in range(epochs):
    print(f'\nEpoch: {i}')
    trainlogs = trainepoch.run(train_loader)
    validlogs = validepoch.run(valid_loader)
    lr_scheduler.step()

    train_logs_list.append(trainlogs)
    valid_logs_list.append(validlogs)
    
    if best_iou_score < validlogs['iou']:
        best_iou_score = validlogs['iou']
        torch.save(model, './best_model_test.pth')
        print("New model saved")
# Out:
# Epoch: 0
# train: 100%|██████████| 79/79 [01:22<00:00,  1.04s/it, DiceLoss - 0.7681, iou - 0.1384]
# valid: 100%|██████████| 187/187 [00:12<00:00, 14.94it/s, DiceLoss - 0.802, iou - 0.1398]
# New model saved
#
# Epoch: 1
# train: 100%|██████████| 79/79 [01:15<00:00,  1.05it/s, DiceLoss - 0.6937, iou - 0.2134]
# valid: 100%|██████████| 187/187 [00:10<00:00, 17.65it/s, DiceLoss - 0.7649, iou - 0.1878]
# New model saved
#
# Epoch: 2
# train: 100%|██████████| 79/79 [01:09<00:00,  1.13it/s, DiceLoss - 0.6556, iou - 0.2528]
# valid: 100%|██████████| 187/187 [00:10<00:00, 17.48it/s, DiceLoss - 0.7576, iou - 0.1913]
# New model saved
#
# Epoch: 3
# train: 100%|██████████| 79/79 [01:11<00:00,  1.11it/s, DiceLoss - 0.6411, iou - 0.266]
# valid: 100%|██████████| 187/187 [00:10<00:00, 17.62it/s, DiceLoss - 0.7536, iou - 0.1918]
# New model saved
#
# Epoch: 4
# train: 100%|██████████| 79/79 [01:09<00:00,  1.13it/s, DiceLoss - 0.6241, iou - 0.2781]
# valid: 100%|██████████| 187/187 [00:10<00:00, 17.85it/s, DiceLoss - 0.7506, iou - 0.1962]
# New model saved
#
# Epoch: 5
# train: 100%|██████████| 79/79 [01:09<00:00,  1.13it/s, DiceLoss - 0.6162, iou - 0.2846]
# valid: 100%|██████████| 187/187 [00:11<00:00, 16.81it/s, DiceLoss - 0.7418, iou - 0.2321]
# New model saved
#
# Epoch: 6
# train: 100%|██████████| 79/79 [01:11<00:00,  1.11it/s, DiceLoss - 0.6094, iou - 0.2885]
# valid: 100%|██████████| 187/187 [00:10<00:00, 17.54it/s, DiceLoss - 0.738, iou - 0.2143]
#
# Epoch: 7
# train: 100%|██████████| 79/79 [01:10<00:00,  1.11it/s, DiceLoss - 0.5968, iou - 0.3027]
# valid: 100%|██████████| 187/187 [00:10<00:00, 17
# valid: 100%|██████████| 187/187 [00:13<00:00, 14.17it/s, DiceLoss - 0.7153, iou - 0.3775]
# New model saved
#
# Epoch: 40
# train: 100%|██████████| 79/79 [01:29<00:00,  1.13s/it, DiceLoss - 0.4345, iou - 0.4956]
# valid: 100%|██████████| 187/187 [00:13<00:00, 13.56it/s, DiceLoss - 0.7163, iou - 0.3618]
#
# Epoch: 41
# train: 100%|██████████| 79/79 [01:32<00:00,  1.17s/it, DiceLoss - 0.4385, iou - 0.4911]
# valid: 100%|██████████| 187/187 [00:12<00:00, 15.25it/s, DiceLoss - 0.7223, iou - 0.3703]
#
# Epoch: 42
# train: 100%|██████████| 79/79 [01:38<00:00,  1.25s/it, DiceLoss - 0.4328, iou - 0.4966]
# valid: 100%|██████████| 187/187 [00:13<00:00, 13.44it/s, DiceLoss - 0.7124, iou - 0.3521]
#
# Epoch: 43
# train: 100%|██████████| 79/79 [01:26<00:00,  1.10s/it, DiceLoss - 0.4275, iou - 0.5044]
# valid: 100%|██████████| 187/187 [00:12<00:00, 15.52it/s, DiceLoss - 0.7086, iou - 0.333]
#
# Epoch: 44
# train: 100%|██████████| 79/79 [01:23<00:00,  1.06s/it, DiceLoss - 0.4213, iou - 0.5134]
# valid: 100%|██████████| 187/187 [00:12<00:00, 15.51it/s, DiceLoss - 0.722, iou - 0.3605]
#
# Epoch: 45
# train: 100%|██████████| 79/79 [01:28<00:00,  1.12s/it, DiceLoss - 0.4267, iou - 0.5063]
# valid: 100%|██████████| 187/187 [00:11<00:00, 16.10it/s, DiceLoss - 0.7099, iou - 0.3423]
#
# Epoch: 46
# train: 100%|██████████| 79/79 [01:21<00:00,  1.03s/it, DiceLoss - 0.4269, iou - 0.5062]
# valid: 100%|██████████| 187/187 [00:11<00:00, 15.68it/s, DiceLoss - 0.7164, iou - 0.3634]
#
# Epoch: 47
# train: 100%|██████████| 79/79 [01:24<00:00,  1.07s/it, DiceLoss - 0.4263, iou - 0.5087]
# valid: 100%|██████████| 187/187 [00:14<00:00, 13.01it/s, DiceLoss - 0.7117, iou - 0.352]
#
# Epoch: 48
# train: 100%|██████████| 79/79 [01:23<00:00,  1.06s/it, DiceLoss - 0.4247, iou - 0.5104]
# valid: 100%|██████████| 187/187 [00:12<00:00, 15.44it/s, DiceLoss - 0.7193, iou - 0.3602]
#
# Epoch: 49
# train: 100%|██████████| 79/79 [01:23<00:00,  1.06s/it, DiceLoss - 0.4324, iou - 0.5]
# valid: 100%|██████████| 187/187 [00:12<00:00, 15.45it/s, DiceLoss - 0.7258, iou - 0.3672]
# CPU times: user 2h 21min 55s, sys: 5min 54s, total: 2h 27min 49s
# Wall time: 1h 14min 30s

# %%
# torch.save(model, './test_last.pth')

# %%
train_logs_df = pd.DataFrame(train_logs_list)
valid_logs_df = pd.DataFrame(valid_logs_list)
train_logs_df.T
# Out:
#                 0         1         2         3         4         5   \
# DiceLoss  0.768084  0.693737  0.655593  0.641066  0.624067  0.616186
# iou       0.138412  0.213375  0.252798  0.265997  0.278063  0.284560
#
#                 6         7         8         9   ...        40        41  \
# DiceLoss  0.609386  0.596764  0.585912  0.580714  ...  0.434518  0.438502
# iou       0.288536  0.302673  0.315909  0.316254  ...  0.495592  0.491103
#
#                 42        43        44        45        46        47  \
# DiceLoss  0.432778  0.427515  0.421330  0.426654  0.426890  0.426279
# iou       0.496560  0.504443  0.513368  0.506265  0.506165  0.508715
#
#                 48        49
# DiceLoss  0.424715  0.432412
# iou       0.510419  0.500008
#
# [2 rows x 50 columns]

# %%
# Тут не дуже ясно чому iou score більше 1 та менше 0 може бути
plt.plot(train_logs_df.index.tolist(), train_logs_df.iou.tolist(), "green", lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.iou.tolist(), "red", lw=3, label = 'Valid')

plt.xlabel('Epochs')
plt.ylabel('IoU Score')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
# plt.plot(train_logs_df.index.tolist(), train_logs_df.jaccard_loss.tolist(), "green", lw=3, label = 'Train')
# plt.plot(valid_logs_df.index.tolist(), valid_logs_df.jaccard_loss.tolist(), "red", lw=3, label = 'Valid')

plt.plot(train_logs_df.index.tolist(), train_logs_df.DiceLoss.tolist(), "green" , lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.DiceLoss.tolist(), "red" , lw=3, label = 'Valid')

plt.xlabel('Epochs')
plt.ylabel('Dice Loss')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
best_model = torch.load('./best_model_test.pth')
# best_model = torch.load('./test_last.pth')

test_images_dir = "./test_images"
test_masks_dir = "./test_masks"

test_data = SegmentationDataset(
    test_df, test_images_dir, test_masks_dir,
    augmentation=get_validation_augmentation(),
)

val_data = SegmentationDataset(
    val_df, validation_img_dir, validation_mask_dir,
    augmentation=get_validation_augmentation(),
)

extra_test_data = SegmentationDataset(
    train_df, train_img_dir, train_mask_dir,
    augmentation=get_validation_augmentation(),
)

# %%
size = 64
threshold = 150
average_iou = []

def visualize_pred(images):
    names = ["Image", "True Mask", "Predicted Mask", "Diff"]
    plt.figure(figsize=(10, 5))
    n = len(images)
    
    for i in range(n):
        plt.subplot(1, n, i + 1)
        plt.title(names[i])
        image = images[i]
        
        if image.shape[0] == 3:
            image = image[0, :, :]
        plt.imshow(image)
    plt.show()


for i in range(8):
    index = np.random.choice(len(test_data))
    
    image_vis, mask_vis = test_data[index]
    
    image_vis = np.array(image_vis).astype(np.float32)
    mask_vis = np.array(mask_vis).astype(np.float32)
    image_vis = image_vis[0, :, :]
    mask_vis = mask_vis[0, :, :]
    
    image_vis = cv2.resize(image_vis, (size, size))
    mask_vis = cv2.resize(mask_vis, (size, size))
    
    
    image_vis = np.stack((image_vis, ) * 3, axis=0)
    

#     image_vis = cv2.flip(image_vis, 1)
#     mask_vis = cv2.flip(mask_vis, 1)
    
    x_tensor = torch.from_numpy(image_vis).unsqueeze(0)
    pr_mask = best_model.predict(x_tensor)
#     temp_mask = pr_mask.squeeze()
    temp_mask = pr_mask.squeeze(0).squeeze(0).detach().cpu().numpy() > 0.5
    pr_mask = pr_mask.squeeze().round()
#     pr_mask = pr_mask.squeeze().numpy() > 0.8
#     print(pr_mask)
    
#     diff_mask = (pr_mask - mask_vis)
#     pr_mask = (pr_mask.squeeze() > 0.8)
    pr_mask = np.array(pr_mask)
    mask_vis = np.array(mask_vis)
    diff_mask = cv2.bitwise_and(pr_mask, mask_vis)
    
    # For the score
    _intersection = cv2.bitwise_and(pr_mask, mask_vis)
    _union = cv2.bitwise_or(pr_mask, mask_vis)
    
#     pr_mask = (pr_mask.squeeze().numpy() > 0.8)
#     temp_mask = pr_mask.squeeze()
    pr_mask *= 255
    pr_mask = pr_mask.astype(np.uint8)
#     pr_mask = cv2.cvtColor(pr_mask,cv2.COLOR_BGR2GRAY)
    thresh = cv2.threshold(pr_mask, threshold, 255, cv2.THRESH_BINARY)[1]
    contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = contours[0] if len(contours) == 2 else contours[1]
    
    for cntr in contours:
        x,y,w,h = cv2.boundingRect(cntr)
        cv2.rectangle(
            pr_mask, 
            (x, y), 
            (x + w, y + h), 
            (255, 0, 0), 
            -1)
#         print("x,y,w,h:", x,y,w,h)
    
#     mask_score = sum(sum(mask_vis))
#     diff_score = sum(sum(diff_mask))
#     if mask_score != 0:
#         total = diff_score / mask_score
#     else:
#         total = 1

    i_score = sum(sum(_intersection))
    u_score = sum(sum(_union))
    if i_score == 0 and u_score == 0:
        total = 1
    else:
        total = i_score / u_score
    average_iou.append(total)
    print("Score: " + str(total))
        
    visualize_pred([
        image_vis, 
        mask_vis, 
        pr_mask,
        temp_mask,
    ])
print("\n\tAverage Score:", sum(average_iou) / len(average_iou))
# Out:
# Score: 1
# Score: 0.5515625
# Score: 0.3512720156555773
# Score: 0.24339839265212398
# Score: 0.0
# Score: 0.0
# Score: 0.02377179080824089
# Score: 0.3512720156555773
# 	Average Score: 0.31515958934643995

# %% [markdown]
# # Train, Validation, Test Splits | for the Classification model

# %%
# remove previous folders
########## RM RF ##########
try:
    import shutil
    shutil.rmtree("train_images")
    shutil.rmtree("train_masks")
    shutil.rmtree("test_images")
    shutil.rmtree("test_masks")
    shutil.rmtree("validation_images")
    shutil.rmtree("validation_masks")
except:
    pass

# create folders to store data
# !mkdir train_images
# !mkdir train_masks

# !mkdir test_images
# !mkdir test_masks

# !mkdir validation_images
# !mkdir validation_masks

# %%
# define data volume
test_data = 0.1
validation_data = 0.1
skip = 6
samples = 1000 * skip

# %%
stop_train = int(samples * (1 - (test_data + validation_data)))

start_test = int(stop_train)
stop_test = int(samples * (1 - validation_data))

start_val = int(stop_test)
stop_val = int(samples)

# %%
remove_idxs_train = []
remove_idxs_test = []
remove_idxs_val = []
size = 128

def create_imgs():
    for i in range(0, stop_train):
        if i % skip == 0:
            try:
                name = train_image_label_df.loc[i, 'id']

                img = get_image(i)
                img = np.array(img)
                img = cv2.resize(img, (size, size))
                cv2.imwrite(f"./train_images/{name}", img)

                mask = get_mask(i)
                mask = np.array(mask)
                mask = cv2.resize(mask, (size, size))
                cv2.imwrite(f"./train_masks/{name}", mask)

            except (FileNotFoundError, RuntimeError) as e:
                remove_idxs_train.append(i)
                print(f"train file {name} not found at index {i}")
                pass
        else:
            remove_idxs_train.append(i)
        
    for j in range(start_test, stop_test):
        if j % skip == 0:
            try:
                name = train_image_label_df.loc[j, 'id']

                img = get_image(j)
                img = np.array(img)
                img = cv2.resize(img, (size, size))
                cv2.imwrite(f"./test_images/{name}", img)

                mask = get_mask(j)
                mask = np.array(mask)
                mask = cv2.resize(mask, (size, size))
                cv2.imwrite(f"./test_masks/{name}", mask)

            except (FileNotFoundError, RuntimeError) as e:
                remove_idxs_test.append(j)
                print(f"test file {name} not found at index {j}")
                pass
        else:
            remove_idxs_test.append(j)
        
    for k in range(start_val, stop_val):
        if k % skip == 0:
            try:
                name = train_image_label_df.loc[k, 'id']

                img = get_image(k)
                img = np.array(img)
                img = cv2.resize(img, (size, size))
                cv2.imwrite(f"./validation_images/{name}", img)

                mask = get_mask(k)
                mask = np.array(mask)
                mask = cv2.resize(mask, (size, size))
                cv2.imwrite(f"./validation_masks/{name}", mask)

            except (FileNotFoundError, RuntimeError) as e:
                remove_idxs_val.append(k)
                print(f"test file {name} not found at index {k}")
                pass
        else:
            remove_idxs_val.append(k)
        
create_imgs()
# Out:
# train file 05c063f5cef5.png not found at index 138
# train file 04f41a8958f7.png not found at index 150
# train file 11f46d9df786.png not found at index 180
# train file 9a335ce0bca4.png not found at index 204
# train file 1c0d8460a527.png not found at index 234
# train file 19ef72ca62b8.png not found at index 252
# train file 08acae0bf785.png not found at index 258
# train file 0a0cbc610620.png not found at index 294
# train file 0b020a7aff0a.png not found at index 318
# train file c7925ab50eb0.png not found at index 354
# train file 0e2691505e53.png not found at index 408
# train file 2204baf77803.png not found at index 474
# train file 12e97ed89297.png not found at index 540
# train file 13ff01cf36f8.png not found at index 576
# train file 16c9f1b33188.png not found at index 630
# train file 1701be774ecb.png not found at index 636
# train file e73f2cc047ad.png not found at index 642
# train file 19fc87ff0612.png not found at index 708
# train file 33c95dbfe335.png not found at index 714
# train file 1b3dcbce0fa2.png not found at index 744
# train file fa447a409bd6.png not found at index 750
# train file 84ed5f7f71bf.png not found at index 780
# train file a1fa5f79671d.png not found at index 804
# train file 1df3e98f79be.png not found at index 810
# train file 215885f7fd71.png not found at index 900
# train file 336d2b8392f9.png not found at index 918
# train file 244776b92aaa.png not found at index 978
# train file 2512da499679.png not found at index 996
# train file 3f79915dd256.png not found at index 1104
# train file 684230477525.png not found at index 1176
# train file 2da1eb17b0b7.png not found at index 1212
# train file 2e37fb0a6193.png not found at index 1230
# train file 2ed1dfce5a95.png not found at index 1242
# train file 32222cc776a2.png not found at index 1332
# train file 646a6a0a9bf2.png not found at index 1344
# train file bb36f3d3ac71.png not found at index 1368
# train file 4cebe94f1fa3.png not found at index 1452
# train file 394536fc0dca.png not found at index 1524
# train file 39cd89772e5e.png not found at index 1536
# train file d342f75ccb55.png not found at index 1542
# train file bfefe70b56ca.png not found at index 1674
# train file 59bc532be971.png not found at index 1722
# train file 41751eb3b214.png not found at index 1734
# train file 744427c7dff8.png not found at index 1758
# train file 4733caa4742e.png not found at index 1872
# train file 49c596c8b1a1.png not found at index 1932
# train file 4cf41c062d0c.png not found at index 2016
# train file 4f0abed3f35c.png not found at index 2076
# train file 51d04316f2c9.png not found at index 2160
# train file 51eb9085f328.png not found at index 2166
# train file 6e5946091b8a.png not found at index 2190
# train file 5b5f7675f4cc.png not found at index 2394
# train file 5e79f836af2c.png not found at index 2472
# train file 603ffc1653fd.png not found at index 2508
# train file 64378532251b.png not found at index 2616
# train file 685114c3c9fd.png not found at index 2724
# train file df565bcf3504.png not found at index 2838
# train file 88e7702b49c4.png not found at index 3084
# train file f6462d1bf586.png not found at index 3132
# train file 835e81040e61.png not found at index 3396
# train file 838c8d86cd36.png not found at index 3402
# train file 847f48f57169.png not found at index 3420
# train file d19ed8d811ad.png not found at index 3450
# train file 8ab8682e8bc6.png not found at index 3558
# train file 90a509d16478.png not found at index 3726
# train file 9b2d4652ad72.png not found at index 3966
# train file 9bc4d429d4e8.png not found at index 3978
# train file e5fc2fa92e65.png not found at index 4014
# train file a0178e3a0d8f.png not found at index 4068
# train file a3d4029a671d.png not found at index 4104
# train file a648b88334e7.png not found at index 4212
# train file ab55abb953d1.png not found at index 4326
# train file ab91cf190fdf.png not found at index 4332
# train file ae3d5da58736.png not found at index 4398
# train file ae8fecc25309.png not found at index 4410
# train file afed0cd3c9a7.png not found at index 4440
# train file b3eae4881218.png not found at index 4530
# train file b621bc3532ca.png not found at index 4572
# train file b689306ef723.png not found at index 4584
# train file b7eb26ddf5a3.png not found at index 4626
# train file b94286e2c027.png not found at index 4662
# train file b9f6129171e3.png not found at index 4680
# test file c04124bd92d8.png not found at index 4842
# test file c0e8c63f22c5.png not found at index 4854
# test file c2596fa5fc65.png not found at index 4884
# test file db55457e9cd2.png not found at index 5004
# test file f7f759f7a4f1.png not found at index 5058
# test file df3d32c8df06.png not found at index 5166
# test file d176b5544d10.png not found at index 5280
# test file d2896d7a3da9.png not found at index 5316
# test file db27626f6cf2.png not found at index 5508
# test file db9f538fa315.png not found at index 5526
# test file dd4db2cfc1dc.png not found at index 5568
# test file e00f9fe0cce5.png not found at index 5622
# test file eeee42a62e29.png not found at index 5940

# %%
print(len(os.listdir("./train_images")))
print(len(os.listdir("./test_images")))
print(len(os.listdir("./validation_masks")))
# Out:
# 718
# 92
# 95

# %%
train_df = train_image_label_df
train_df = train_df.head(stop_train)
train_df = train_df.drop(remove_idxs_train) # TODO: fix deletion of features


test_df = train_image_label_df.iloc[start_test : stop_test]
test_df = test_df.drop(remove_idxs_test)

val_df = train_image_label_df.iloc[start_val : stop_val]
val_df = val_df.drop(remove_idxs_val)

# %% [markdown]
# # Classification model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from timeit import default_timer as timer

# %%
def get_class_training_augmentation():
    train_transform = [    
        Resize(128, 128),
        album.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=30, p=0.5),
        album.RGBShift(r_shift_limit=25, g_shift_limit=25, b_shift_limit=25, p=0.75),
        album.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.75),
        album.OneOf(
            [
                album.HorizontalFlip(p=0.5),
#                 album.VerticalFlip(p=0.5),
#                 album.RandomRotate90(p=0.75),
#                 album.CenterCrop(128, 128),
                album.GaussianBlur(p=0.5),
                album.IAASharpen(p=0.5)
            ],
            p=0.75,
        ),
        album.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ]
    return album.Compose(train_transform)

# %%
def get_class_validation_augmentation():
    train_transform = [    
        Resize(128, 128),
        album.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ]
    return album.Compose(train_transform)

# %%
train_transform = torchvision.transforms.Compose([
                  torchvision.transforms.Resize(size=(128, 128)),
                  torchvision.transforms.ColorJitter(brightness=0.5),
                  torchvision.transforms.RandomRotation(degrees=(10, -10)),
                  torchvision.transforms.RandomHorizontalFlip(),
#                   torchvision.transforms.RandomVerticalFlip(),
                  torchvision.transforms.ToTensor(),
                  torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = torchvision.transforms.Compose([
                 torchvision.transforms.Resize(size=(128, 128)),
                 torchvision.transforms.ToTensor(),
                 torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
class ClassificationDataset(Dataset):
    def __init__(self, 
                 annotations_file, 
                 img_dir,
                 augmentation=None):
        self.img_labels = annotations_file
        self.img_dir = img_dir
        self.augmentation = augmentation

    def __len__(self):
        try:
            return len(self.img_labels)
        except TypeError:
            return 1

        

    def __getitem__(self, idx):
            img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
            
            image = Image.open(img_path)
            image = np.array(image)
#             print(image.shape)
            image = np.stack((image, ) * 3, axis=-1)
#             print(image.shape)
            image = Image.fromarray((image).astype(np.uint8))
            
            label = self.img_labels.iloc[idx, 1]
            label = torch.tensor(label.astype(np.uint8))
            
            image = self.augmentation(image)
            
#             if self.augmentation is not None:
#                 image = self.augmentation(image=image)['image']
                
#             print(image.shape)
            
            return image, label

# %%
train_dataset_class = ClassificationDataset(
                        train_df, 
                        train_img_dir, 
                        augmentation=train_transform,
)

valid_dataset_calss = ClassificationDataset(
                        val_df, 
                        validation_img_dir, 
                        augmentation=test_transform,
)

train_loader_class = DataLoader(train_dataset_class, batch_size=4, shuffle=True, num_workers=4)
valid_loader_class = DataLoader(valid_dataset_calss, batch_size=4, shuffle=False, num_workers=4)

# %%
# train_dataset_class = ClassificationDataset(
#                         train_df, 
#                         train_img_dir, 
#                         augmentation=get_class_training_augmentation(),
# )

# valid_dataset_calss = ClassificationDataset(
#                         val_df, 
#                         validation_img_dir, 
#                         augmentation=get_class_validation_augmentation(),
# )

# train_loader_class = DataLoader(train_dataset_class, batch_size=64, shuffle=True, num_workers=4)
# valid_loader_class = DataLoader(valid_dataset_calss, batch_size=8, shuffle=True, num_workers=4)

# %%
train_class_fetures, train_class_labels = next(iter(train_loader_class))

# %%
model = models.resnet50(pretrained=True)
# model = models.vgg19(pretrained=True)
# model = models.resnet34(pretrained=True)
# model = models.resnet18(pretrained=True)
# model = models.vgg19(pretrained='imagenet')
# model = models.densenet201(pretrained=True)
criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), weight_decay=0.3)
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.2)
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
freeze_layers = 5
ct = 0
for child in model.children():
    ct += 1
    if ct < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
            
model.fc = nn.Sequential(
    nn.Dropout(p=0.5),
    nn.Linear(2048, 4)
)

# model.fc = torch.nn.Linear(in_features=2048, out_features=4)

# # Define loss function and Optimizer. Select all model parameters to be fined-tuned
# criterion = torch.nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)

# %%
# model = torchvision.models.vgg19(pretrained=True)
save_file_name = 'classification_model.pt'
history = []
valid_acc_history = [0, 0]

# %%
# for param in model.parameters():
#     param.requires_grad = False
# n_inputs = model.classifier[6].in_features


# model.classifier[6] = nn.Sequential(
# nn.Linear(n_inputs, 128), nn.Sigmoid(), nn.Dropout(0.2),
# nn.Linear(128, 4), nn.LogSoftmax(dim=1))

# %%
total_params = sum(p.numel() for p in model.parameters())
print('Number of Parameters: {}'.format(total_params))
total_trainable_params = sum(
p.numel() for p in model.parameters() if p.requires_grad)
print('Number of Training Parameters: {}'.format(total_trainable_params))
# Out:
# Number of Parameters: 23516228
# Number of Training Parameters: 23506692

# %%
# criterion = nn.NLLLoss()
# optimizer = torch.optim.Adam(model.parameters())
# criterion = torch.nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=0.0085)

epochs_no_improve = 0
valid_acc_min = 0
# torch.cuda.empty_cache()

valid_max_acc = 0

try:
    print(f'Model has been trained for: {model.epochs} epochs.\n')
except:
    model.epochs = 0

# %%
EPOCHS = 15
overall_start = timer()

for epoch in range(EPOCHS):

    train_loss = 0.0
    valid_loss = 0.0

    train_acc = 0
    valid_acc = 0

    model.train()
    start = timer()

    for ii, (data, target) in enumerate(train_loader_class):

        target = target.type(torch.LongTensor)
        optimizer.zero_grad()
#         torch.cuda.empty_cache()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
#         scheduler.step(epoch)

        train_loss += loss.item() * data.size(0)
        _, pred = torch.max(output, dim=1)
        correct_tensor = pred.eq(target.data.view_as(pred))
        correct = np.squeeze(correct_tensor.numpy())
        accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))
        train_acc += accuracy.item() * data.size(0)

        print(
            f'Epoch: {epoch}\t{100 * (ii + 1) / len(train_loader_class):.2f}% complete. {timer() - start:.2f} seconds elapsed in epoch.',
            end='\r')

    else:
        model.epochs += 1
        with torch.no_grad():
            model.eval()
            for data, target in valid_loader_class:
#                 if CUDA:
#                     data, target = data.cuda(), target.cuda()
                target = target.type(torch.LongTensor)
                output = model(data)
                loss = criterion(output, target)
                valid_loss += loss.item() * data.size(0)
                _, pred = torch.max(output, dim=1)
                correct_tensor = pred.eq(target.data.view_as(pred))
                accuracy = torch.mean(
                    correct_tensor.type(torch.FloatTensor))

                valid_acc += accuracy.item() * data.size(0)


            train_loss = train_loss / len(train_loader_class.dataset)
            valid_loss = valid_loss / len(valid_loader_class.dataset)


            train_acc = train_acc / len(train_loader_class.dataset)
            valid_acc = valid_acc / len(valid_loader_class.dataset)

            history.append([train_loss, valid_loss, train_acc, valid_acc])

            
            print(
                f'\nEpoch: {epoch} \tTraining Loss: {train_loss:.4f} \tValidation Loss: {valid_loss:.4f}'
            )
            print(
                f'\t\tTraining Accuracy: {100 * train_acc:.2f}%\t Validation Accuracy: {100 * valid_acc:.2f}%'
            )

            # Save the model if validation loss decreases
            print(max(valid_acc_history))
            if max(valid_acc_history) < valid_acc:
                torch.save(model.state_dict(), save_file_name)
                epochs_no_improve = 0
                valid_loss_min = valid_loss
                valid_best_acc = valid_acc
                best_epoch = epoch

            # Otherwise increment count of epochs with no improvement
            else:
                epochs_no_improve += 1
#                 if epochs_no_improve >= 3:
#                     print(
#                         f'\nEarly Stopping! Total epochs: {epoch}. Best epoch: {best_epoch} with loss: {valid_loss_min:.2f} and acc: {100 * valid_acc:.2f}%'
#                     )
#                     total_time = timer() - overall_start
#                     print(
#                         f'{total_time:.2f} total seconds elapsed. {total_time / (epoch+1):.2f} seconds per epoch.'
#                     )
#                     model.load_state_dict(torch.load(save_file_name))
#                     model.optimizer = optimizer
#                     history = pd.DataFrame(
#                         history,
#                         columns=[
#                             'train_loss', 'valid_loss', 
#                             'train_acc', 'valid_acc'
#                         ])
#                     break
            valid_acc_history.append(valid_acc)


model.optimizer = optimizer
total_time = timer() - overall_start
print(
    f'\nBest epoch: {best_epoch} with loss: {valid_loss_min:.2f} and acc: {100 * valid_best_acc:.2f}%'
)
print(
    f'{total_time:.2f} total seconds elapsed. {total_time / (epoch + 1):.2f} seconds per epoch.'
)
history = pd.DataFrame(
    history,
    columns=['train_loss', 'valid_loss', 'train_acc', 'valid_acc'])
eps = range(1, EPOCHS-1)
# Out:
# Epoch: 0	100.00% complete. 156.32 seconds elapsed in epoch.
# Epoch: 0 	Training Loss: 1.3687 	Validation Loss: 1.2676
# 		Training Accuracy: 36.77%	 Validation Accuracy: 48.42%
# 0
# Epoch: 1	100.00% complete. 163.94 seconds elapsed in epoch.
# Epoch: 1 	Training Loss: 1.2591 	Validation Loss: 1.2743
# 		Training Accuracy: 49.03%	 Validation Accuracy: 43.16%
# 0.48421052662949815
# Epoch: 2	100.00% complete. 157.78 seconds elapsed in epoch.
# Epoch: 2 	Training Loss: 1.2189 	Validation Loss: 1.2974
# 		Training Accuracy: 50.70%	 Validation Accuracy: 44.21%
# 0.48421052662949815
# Epoch: 3	100.00% complete. 166.95 seconds elapsed in epoch.
# Epoch: 3 	Training Loss: 1.1985 	Validation Loss: 1.2026
# 		Training Accuracy: 51.67%	 Validation Accuracy: 47.37%
# 0.48421052662949815
# Epoch: 4	100.00% complete. 161.24 seconds elapsed in epoch.
# Epoch: 4 	Training Loss: 1.2424 	Validation Loss: 1.2987
# 		Training Accuracy: 49.72%	 Validation Accuracy: 44.21%
# 0.48421052662949815
# Epoch: 5	100.00% complete. 159.03 seconds elapsed in epoch.
# Epoch: 5 	Training Loss: 1.2740 	Validation Loss: 1.3181
# 		Training Accuracy: 47.63%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 6	100.00% complete. 175.04 seconds elapsed in epoch.
# Epoch: 6 	Training Loss: 1.3109 	Validation Loss: 1.3361
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 7	100.00% complete. 161.13 seconds elapsed in epoch.
# Epoch: 7 	Training Loss: 1.3271 	Validation Loss: 1.3427
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 8	100.00% complete. 158.62 seconds elapsed in epoch.
# Epoch: 8 	Training Loss: 1.3311 	Validation Loss: 1.3412
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 9	100.00% complete. 165.12 seconds elapsed in epoch.
# Epoch: 9 	Training Loss: 1.3235 	Validation Loss: 1.3322
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 10	100.00% complete. 164.85 seconds elapsed in epoch.
# Epoch: 10 	Training Loss: 1.3126 	Validation Loss: 1.3274
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 11	100.00% complete. 169.48 seconds elapsed in epoch.
# Epoch: 11 	Training Loss: 1.3095 	Validation Loss: 1.3252
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 12	100.00% complete. 156.35 seconds elapsed in epoch.
# Epoch: 12 	Training Loss: 1.3058 	Validation Loss: 1.3238
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 13	100.00% complete. 163.30 seconds elapsed in epoch.
# Epoch: 13 	Training Loss: 1.3047 	Validation Loss: 1.3228
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
# Epoch: 14	100.00% complete. 163.17 seconds elapsed in epoch.
# Epoch: 14 	Training Loss: 1.3054 	Validation Loss: 1.3225
# 		Training Accuracy: 44.29%	 Validation Accuracy: 40.00%
# 0.48421052662949815
#
# Best epoch: 0 with loss: 1.27 and acc: 48.42%
# 2517.32 total seconds elapsed. 167.82 seconds per epoch.

# %%
# print(history)
# loss_train = history[0]
# loss_test = history[1]
# acc_train = history[2]
# acc_valid = history[3]
loss_train = history['train_loss']
loss_test = history['valid_loss']
acc_train = history['train_acc']
acc_valid = history['valid_acc']
fig = plt.figure(figsize=(5,5))
plt.plot(loss_train, 'g', label='Training loss')
plt.plot(loss_test, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show() 
fig = plt.figure(figsize=(5,5))
plt.plot(acc_train, 'g', label='Training Accuracy')
plt.plot(acc_valid, 'b', label='Validation Accuracy')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# def accuracy(out, labels):
#     _, pred = torch.max(out, dim=1)
#     return torch.sum(pred==labels).item()

# %%
# epochs = 12
# print_every = 10
# valid_loss_min = np.Inf
# val_loss = []
# val_acc = [0]
# train_loss = []
# train_acc = [0]
# total_step = len(train_loader_class)

# for epoch in range(epochs):
#     running_loss = 0.0
# #     scheduler.step(epoch)
#     correct = 0
#     total=0
#     print(f'Epoch {epoch}\n')
#     for batch_idx, (data_, target_) in enumerate(train_loader_class):
#         target_ = target_.type(torch.LongTensor)
#         optimizer.zero_grad()
# #         print(type(target_), target_)
#         outputs = model(data_)
# #         print(type(outputs))
#         loss = criterion(outputs, target_)
#         loss.backward()
#         optimizer.step()
#         scheduler.step(epoch)
        
#         running_loss += loss.item()
#         _,pred = torch.max(outputs, dim=1)
#         correct += torch.sum(pred==target_).item()
        
#         total += target_.size(0)
#         if (batch_idx) % 20 == 0:
#             print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
#                    .format(epoch, epochs, batch_idx, total_step, loss.item()))
            
#     train_accuracy = correct / total
#     train_acc.append(train_accuracy)
#     train_loss.append(running_loss / total_step)
#     print(f'\ntrain loss: {np.mean(train_loss):.4f}, train acc: {(correct / total)}')
#     batch_loss = 0
#     total_t = 0
#     correct_t = 0
#     with torch.no_grad():
#         model.eval()
#         for data_t, target_t in (valid_loader_class):
#             target_t = target_t.type(torch.LongTensor)
            
#             outputs_t = model(data_t)
#             loss_t = criterion(outputs_t, target_t)
#             batch_loss += loss_t.item()
#             _, pred_t = torch.max(outputs_t, dim=1)
#             correct_t += torch.sum(pred_t==target_t).item()
#             total_t += target_t.size(0)
            
#         validation_accuracy = correct_t / total_t
#         val_acc.append(validation_accuracy)
#         val_loss.append(batch_loss / len(valid_loader_class))
        
#         print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(correct_t / total_t)}\n')
          
# #         print(validation_accuracy[-1], validation_accuracy)
# #         print(val_acc[0:-1])
#         if (max(val_acc[0:-1]) < validation_accuracy):
#             valid_loss_min = batch_loss
#             torch.save(model.state_dict(), 'classification_model.pt')
#             print('Detected network improvement, saving current model')
#     model.train()

# %%
# fig = plt.figure(figsize=(10, 5))
# plt.title("Train - Validation Loss")
# plt.plot( train_loss, label='train')
# plt.plot( val_loss, label='validation')
# plt.xlabel('num_epochs', fontsize=12)
# plt.ylabel('loss', fontsize=12)
# plt.legend(loc='best')

# %%
# fig = plt.figure(figsize=(10, 5))
# plt.title("Train - Validation Accuracy")
# plt.plot(train_acc, label='train')
# plt.plot(val_acc, label='validation')
# plt.xlabel('num_epochs', fontsize=12)
# plt.ylabel('accuracy', fontsize=12)
# plt.legend(loc='best')

# %%
train_dataset_class = ClassificationDataset(
                        test_df, 
                        test_img_dir, 
                        augmentation=test_transform,
)


test_loader_class = DataLoader(train_dataset_class, batch_size=16, shuffle=True, num_workers=4)

# %%
test_class_fetures, test_class_labels = next(iter(test_loader_class))

# %%
model.load_state_dict(torch.load('classification_model.pt'))
# Out:
# <All keys matched successfully>

# %%
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
with torch.no_grad():
    model.eval()
    for i, ax in enumerate(axis.flat):
        image, label = test_class_fetures[i], test_class_labels[i]
        ax.imshow(image[0, :, :])
        image_tensor = image.unsqueeze_(0)
        output_ = model(image_tensor)
        _, index = torch.max(output_, 1)
        percentage = torch.nn.functional.softmax(output_, dim=1)[0] * 100
        result = output_.argmax()
        print(index, percentage[0], percentage[1], percentage[2], percentage[3])
        print(sum([percentage[0], percentage[1], percentage[2], percentage[3]]), "\n")
        ax.set(title = f"{label} + {result}")
# Out:
# tensor([1]) tensor(13.3050) tensor(46.9888) tensor(25.8127) tensor(13.8936)
# tensor(100.)
#
# tensor([1]) tensor(17.8756) tensor(39.2943) tensor(25.4405) tensor(17.3896)
# tensor(100.0000)
#
# tensor([1]) tensor(17.3827) tensor(33.0137) tensor(29.6492) tensor(19.9544)
# tensor(100.)
#
# tensor([1]) tensor(17.1857) tensor(46.1619) tensor(20.0059) tensor(16.6465)
# tensor(100.0000)
#
# tensor([1]) tensor(20.9142) tensor(37.7491) tensor(20.2247) tensor(21.1119)
# tensor(100.0000)
#
# tensor([1]) tensor(15.1708) tensor(41.3901) tensor(26.1150) tensor(17.3241)
# tensor(100.)
#
# tensor([0]) tensor(41.9905) tensor(15.6099) tensor(23.9199) tensor(18.4797)
# tensor(100.)
#
# tensor([0]) tensor(42.0803) tensor(18.4902) tensor(24.0774) tensor(15.3521)
# tensor(100.0000)
#
# tensor([1]) tensor(16.2424) tensor(45.6403) tensor(20.3410) tensor(17.7763)
# tensor(100.)
#
# tensor([0]) tensor(38.0936) tensor(18.7234) tensor(19.7608) tensor(23.4222)
# tensor(100.)
#
# tensor([0]) tensor(45.0484) tensor(19.1963) tensor(13.6745) tensor(22.0808)
# tensor(100.)
#
# tensor([0]) tensor(49.2810) tensor(15.6694) tensor(13.5534) tensor(21.4963)
# tensor(100.)
#
# tensor([1]) tensor(27.9246) tensor(31.4469) tensor(19.7011) tensor(20.9274)
# tensor(100.)
#
# tensor([0]) tensor(34.5293) tensor(27.9364) tensor(20.5222) tensor(17.0121)
# tensor(100.)
#
# tensor([0]) tensor(28.0174) tensor(27.2869) tensor(26.1741) tensor(18.5216)
# tensor(100.0000)

# %% [markdown]
# # Submission file

# %%
print("Loading submission...")
# Out:
# Loading submission...

# %%
# !ls ../input/modelv2/
# Out:
# 'best_model_test (6).pth'

# %%
model_dir = './best_model_test.pth'
test_images = "../input/siim-covid19-detection/test"

# if not os.path.exists(model_dir):
#     model_dir = '../input/modelv2/best_model_v2.pth'
best_model = torch.load(model_dir)

# %%
import shutil
shutil.rmtree("train_images")
shutil.rmtree("train_masks")
shutil.rmtree("test_images")
shutil.rmtree("test_masks")
shutil.rmtree("validation_images")
shutil.rmtree("validation_masks")

# !mkdir test_submission_images

# %%
print("Converting dicom files")
# Out:
# Converting dicom files

# %%
segmentation_test_transform = album.Compose([    
    Resize(64, 64),
#     album.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#     ToTensorV2(),
])

classification_test_transform = album.Compose([    
    Resize(128, 128),
    album.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2(),
])

# %%
size = 64
threshold = 150

def get_mask_box(mask, x_scale, y_scale):
    boxes, probs = [], []
    mask *= 255
    mask = mask.astype(np.uint8)

    thresh = cv2.threshold(mask, threshold, 255, cv2.THRESH_BINARY)[1]
    contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     print(contours)
    contours = contours[0] if len(contours) == 2 else contours[1]
    
    for cntr in contours:
#         print(cntr)
        x, y, w, h = cv2.boundingRect(cntr)
        
        x *= x_scale
        y *= y_scale
        w *= x_scale
        h *= y_scale
#         cv2.rectangle(
#             mask, 
#             (x, y), 
#             (x + w, y + h), 
#             (255, 0, 0), 
#             -1)
        
#         print("here")
        
        area = cv2.contourArea(cntr) * size
        
        x = int(x)
        y = int(y)
        w = int(w)
        h = int(h)
        
        boxes.append(f"{x} {y} {x + w} {y + h}")
        probs.append(area / (w * h))
#         print(area)
    return boxes, probs

# %%
test_dir = "../input/siim-covid19-detection/test/"
submission_df = pd.DataFrame(columns = ["id", "PredictionString"])
# SIIM-FISABIO-RSNA-Chest-Anomaly-64_60-256_40_v34

# %%
def find_study_level(dir):
    dirs = list(os.listdir(dir))
    dirs = sorted(dirs)

    for directory in dirs:
        for root, directories, filenames in os.walk(dir + directory):
            for filename in filenames:
                
                curr_image_dir = os.path.join(root, filename)
                id = directory + "_study"                
                pred_string = ""
                
                try:
                    data_file = dicom.dcmread(curr_image_dir)
                    image = data_file.pixel_array

                    image = np.array(image).astype(np.float32)
                    image = (image / image.max() * 255)
                    image = np.stack((image, ) * 3, axis=-1)
                    image = classification_test_transform(image=image)['image']

                    image_tensor = image.unsqueeze(0)

                    output_ = model(image_tensor)
                    percentage = torch.nn.functional.softmax(output_, dim=1)[0]

                    for i in classes:
                        pred_string += f"{classes[i]} {percentage[i]} 0 0 1 1 "

                except:
                    pred_string = "negative 0.25 0 0 1 1 typical 0.25 0 0 1 1 indeterminate 0.25 0 0 1 1 atypical 0.25 0 0 1 1"
            
                print(pred_string)
                new_row = {"id": id, "PredictionString": pred_string}
                global submission_df
                submission_df = submission_df.append(new_row, ignore_index=True)
#                 return
            
            
find_study_level(test_dir)
# Out:
# negative 0.28977447748184204 0 0 1 1 typical 0.2073972076177597 0 0 1 1 indeterminate 0.33001381158828735 0 0 1 1 atypical 0.17281442880630493 0 0 1 1
# negative 0.06876116991043091 0 0 1 1 typical 0.66678386926651 0 0 1 1 indeterminate 0.14632733166217804 0 0 1 1 atypical 0.11812756955623627 0 0 1 1
# negative 0.21853512525558472 0 0 1 1 typical 0.3316398561000824 0 0 1 1 indeterminate 0.24736475944519043 0 0 1 1 atypical 0.20246022939682007 0 0 1 1
# negative 0.18453308939933777 0 0 1 1 typical 0.41773679852485657 0 0 1 1 indeterminate 0.20762602984905243 0 0 1 1 atypical 0.19010409712791443 0 0 1 1
# negative 0.2105231136083603 0 0 1 1 typical 0.37675154209136963 0 0 1 1 indeterminate 0.2623429596424103 0 0 1 1 atypical 0.15038244426250458 0 0 1 1
# negative 0.16643473505973816 0 0 1 1 typical 0.40002498030662537 0 0 1 1 indeterminate 0.18965375423431396 0 0 1 1 atypical 0.24388648569583893 0 0 1 1
# negative 0.25618815422058105 0 0 1 1 typical 0.31022122502326965 0 0 1 1 indeterminate 0.23595638573169708 0 0 1 1 atypical 0.19763420522212982 0 0 1 1
# negative 0.27498239278793335 0 0 1 1 typical 0.2674599885940552 0 0 1 1 indeterminate 0.28945010900497437 0 0 1 1 atypical 0.16810749471187592 0 0 1 1
# negative 0.18641358613967896 0 0 1 1 typical 0.40397441387176514 0 0 1 1 indeterminate 0.20333082973957062 0 0 1 1 atypical 0.2062811702489853 0 0 1 1
# negative 0.4265357255935669 0 0 1 1 typical 0.1621144562959671 0 0 1 1 indeterminate 0.2510988712310791 0 0 1 1 atypical 0.16025102138519287 0 0 1 1
# negative 0.24590519070625305 0 0 1 1 typical 0.3366275727748871 0 0 1 1 indeterminate 0.2530711889266968 0 0 1 1 atypical 0.16439597308635712 0 0 1 1
# 1259  ff2cc4de58c5_study  negative 0.34075358510017395 0 0 1 1 typical 0...
# 1260  ff2f0a744930_study  negative 0.14530165493488312 0 0 1 1 typical 0...
# 1261  ff88940dce8b_study  negative 0.3251088261604309 0 0 1 1 typical 0....
# 1262  fff7ef24961f_study  negative 0.1962941437959671 0 0 1 1 typical 0....
#
# [1263 rows x 2 columns]

# %%
size = 64
a = 0

def find_images_level(dir):
    for root, directories, filenames in os.walk(dir): 
        for filename in filenames:  
#             global a
#             a += 1
            
            curr_image_dir = os.path.join(root, filename)            
            id = filename.replace(".dcm", "_image")
            
            try:
                data_file = dicom.dcmread(curr_image_dir)
                image = data_file.pixel_array
                image = np.array(image).astype(np.float32)
                x_scale, y_scale = image.shape[0] / size, image.shape[1] / size

                image = segmentation_test_transform(image=image)['image']
                image = np.stack((image, ) * 3, axis=0)
                image = (image / image.max() * 255).astype(np.float32)    

                image_tensor = torch.from_numpy(image).unsqueeze(0)
                
                pr_mask = best_model.predict(image_tensor)
                pr_mask = pr_mask.squeeze()
                pr_mask = np.array(pr_mask).round()
#                 pr_mask = pr_mask.squeeze(0).squeeze(0).detach().cpu().numpy() > 0.75
#                 print(pr_mask)
                pred_string = ""
                boxes, probs = get_mask_box(pr_mask, x_scale, y_scale)
#                 print(boxes, probs)

                if len(boxes) != 0:
                    for i in range(len(boxes)):
                        if (probs[i] > 0.0001) and (probs[i] < 0.99):
#                             box = 
                            pred_string += f"opacity {probs[i]} {boxes[i]} "
#                         else:
#                             pred_string += f"opacity 1 {boxes[i]} "
                    if len(pred_string) <= 1:
                        pred_string = "none 1 0 0 1 1"
                else:
                    pred_string = "none 1 0 0 1 1"

            except RuntimeError:
                pred_string = "none 1 0 0 1 1"
                
#             print(pred_string)
#             if a > 10:
#                 return
            new_row = {"id": id, "PredictionString": pred_string}
            global submission_df
            submission_df = submission_df.append(new_row, ignore_index=True)
        
find_images_level(test_dir)

# %%
# !rm -rf best_model_test.pth
# !rm -rf classification_model.pt

# %%
print("Done")
# Out:
# Done

# %%
submission_df = submission_df.drop_duplicates(subset="id", keep="last")
submission_df = submission_df[["id", "PredictionString"]]

# %%
submission_df.to_csv('./submission.csv', index=False)
submission_df
# Out:
#                       id                                   PredictionString
# 0     00188a671292_study  negative 0.28977447748184204 0 0 1 1 typical 0...
# 1     004bd59708be_study  negative 0.06876116991043091 0 0 1 1 typical 0...
# 2     00508faccd39_study  negative 0.21853512525558472 0 0 1 1 typical 0...
# 3     006486aa80b2_study  negative 0.18453308939933777 0 0 1 1 typical 0...
# 4     00655178fdfc_study  negative 0.2105231136083603 0 0 1 1 typical 0....
# ...                  ...                                                ...
# 2521  a43200bd5ceb_image  opacity 0.029700417662123373 584 1285 1022 208...
# 2522  37bf83df1b86_image  opacity 0.012848777767450506 2011 728 2881 258...
# 2523  b30d2aef985f_image  opacity 0.012924768452392288 2392 1192 3153 28...
# 2524  a37a362df0ac_image  opacity 0.011716286279330803 2229 1590 2935 26...
# 2525  a0f473f71878_image  opacity 0.03084469599519767 1776 265 2283 1415...
#
# [2477 rows x 2 columns]
